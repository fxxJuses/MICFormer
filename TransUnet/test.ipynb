# %%
import torch 
from dataset.MMWHS import get_datasets,get_datasets_noPad,get_datasets_Aug
from models.segmentation.trans_unet import TransUNet
from utils2 import reload_ckpt_bis , post_trans , decollate_batch , inference
import nibabel as nib
import numpy as np
from monai import transforms
import monai

# %%
val_transform = transforms.Compose(
        [
            transforms.NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
        ]
    )

full_train_dataset, l_val_dataset, bench_dataset = get_datasets_Aug(1234, fold_number=0,val_transforms=val_transform)
train_loader = torch.utils.data.DataLoader(full_train_dataset, batch_size=1, shuffle=True,
                                            num_workers=0, pin_memory=False, drop_last=False)
val_loader = torch.utils.data.DataLoader(l_val_dataset, batch_size=1, shuffle=False,
                                            pin_memory=True, num_workers=0)
bench_loader = torch.utils.data.DataLoader(bench_dataset, batch_size=1, num_workers=0)

# %%
model_1 = TransUNet(
            input_shape= (2,128,128,128), 
            num_classes = 8,
            # num_channels_list = [32,64,128,256,380,512],
            num_channels_list = [16,32,64,128,190,256],
            kernel_size=3,
            scale_factor=2,)
checkpoint = "/home/fanxx/fxx/Multi-modal-Segmentation/MMWHS_pre/Multi_modal/TransUnet/runs/logs_base/model_noPad_2/model_best.pth.tar"
reload_ckpt_bis(checkpoint, model_1,device='cuda:0')
model_1.cuda()
# Out:
# => loading checkpoint /home/fanxx/fxx/Multi-modal-Segmentation/MMWHS_pre/Multi_modal/TransUnet/runs/logs_base/model_noPad_2/model_best.pth.tar
# TransUNet(
#   (predict_softmax): Softmax(dim=1)
#   (encoder): ConvEncoder(
#     (conv_blocks): ModuleList(
#       (0): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(128, 190, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(190, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(190, 190, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(190, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(190, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (downscaling_layers): ModuleList(
#       (0): MaxPool3dDownscale(
#         (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): MaxPool3dDownscale(
#         (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (2): MaxPool3dDownscale(
#         (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (3): MaxPool3dDownscale(
#         (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (4): MaxPool3dDownscale(
#         (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (decoder): ConvTransDecoder(
#     (conv_blocks): ModuleList(
#       (0): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(380, 190, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(190, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(190, 190, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(190, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): DoubleConvBlock(
#         (conv_block_1): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv_block_2): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): ReLU()
#           (normalization): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (upscaling_layers): ModuleList(
#       (0): TransposeConv3dUpsample(
#         (transpose_conv): ConvTranspose3d(256, 190, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#       )
#       (1): TransposeConv3dUpsample(
#         (transpose_conv): ConvTranspose3d(190, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#       )
#       (2): TransposeConv3dUpsample(
#         (transpose_conv): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#       )
#       (3): TransposeConv3dUpsample(
#         (transpose_conv): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#       )
#       (4): TransposeConv3dUpsample(
#         (transpose_conv): ConvTranspose3d(32, 16, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#       )
#     )
#     (attention_blocks): ModuleList(
#       (0): PatchifyVisionMultiheadAttention(
#         (patch_embed_skip): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(190, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (patch_embed_decoder): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (vision_attention): VisionMultiheadAttention(
#           (query_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (key_val_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (multihead_attention_block): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#           )
#         )
#         (upscale_attention): TransposeConv3dUpsample(
#           (transpose_conv): ConvTranspose3d(64, 190, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         )
#         (normalization): Identity()
#       )
#       (1): PatchifyVisionMultiheadAttention(
#         (patch_embed_skip): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (patch_embed_decoder): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(190, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (vision_attention): VisionMultiheadAttention(
#           (query_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (key_val_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (multihead_attention_block): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#           )
#         )
#         (upscale_attention): TransposeConv3dUpsample(
#           (transpose_conv): ConvTranspose3d(64, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#         )
#         (normalization): Identity()
#       )
#       (2): PatchifyVisionMultiheadAttention(
#         (patch_embed_skip): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(64, 64, kernel_size=(4, 4, 4), stride=(4, 4, 4))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (patch_embed_decoder): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(128, 64, kernel_size=(4, 4, 4), stride=(4, 4, 4))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (vision_attention): VisionMultiheadAttention(
#           (query_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (key_val_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (multihead_attention_block): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#           )
#         )
#         (upscale_attention): TransposeConv3dUpsample(
#           (transpose_conv): ConvTranspose3d(64, 64, kernel_size=(4, 4, 4), stride=(4, 4, 4))
#         )
#         (normalization): Identity()
#       )
#       (3): PatchifyVisionMultiheadAttention(
#         (patch_embed_skip): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(32, 64, kernel_size=(8, 8, 8), stride=(8, 8, 8))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (patch_embed_decoder): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(64, 64, kernel_size=(8, 8, 8), stride=(8, 8, 8))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (vision_attention): VisionMultiheadAttention(
#           (query_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (key_val_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (multihead_attention_block): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#           )
#         )
#         (upscale_attention): TransposeConv3dUpsample(
#           (transpose_conv): ConvTranspose3d(64, 32, kernel_size=(8, 8, 8), stride=(8, 8, 8))
#         )
#         (normalization): Identity()
#       )
#       (4): PatchifyVisionMultiheadAttention(
#         (patch_embed_skip): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(16, 64, kernel_size=(16, 16, 16), stride=(16, 16, 16))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (patch_embed_decoder): Conv3DDropoutNormActivation(
#           (convolution): Conv3d(32, 64, kernel_size=(16, 16, 16), stride=(16, 16, 16))
#           (dropout): Dropout3d(p=0, inplace=False)
#           (activation): Identity()
#           (normalization): Identity()
#         )
#         (vision_attention): VisionMultiheadAttention(
#           (query_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (key_val_pos_encoder): PositionalEncodingPermute3D(
#             (penc): PositionalEncoding3D()
#           )
#           (multihead_attention_block): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#           )
#         )
#         (upscale_attention): TransposeConv3dUpsample(
#           (transpose_conv): ConvTranspose3d(64, 16, kernel_size=(16, 16, 16), stride=(16, 16, 16))
#         )
#         (normalization): Identity()
#       )
#     )
#   )
#   (output_layer): Conv3d(16, 8, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
def meandice(pred, label , num_class):
    sumdice = 0
    smooth = 1e-6

    for i in range(1, num_class):
        pred_bin = (pred==i)*1
        label_bin = (label==i)*1

        pred_bin = pred_bin.contiguous().view(pred_bin.shape[0], -1)
        label_bin = label_bin.contiguous().view(label_bin.shape[0], -1)

        intersection = (pred_bin * label_bin).sum()
        dice = (2. * intersection + smooth) / (pred_bin.sum() + label_bin.sum() + smooth)
        sumdice += dice

    return sumdice/(num_class - 1) # 有背景类

# %%
mean_dice =[]
mean_hd95 = []
mean_MIOU = []
with torch.no_grad():
    for i , batch in enumerate(val_loader):
        patient_id = batch["patient_id"]
        val_inputs, val_labels = (
                batch["image"].cuda(),
                batch["label"].cuda(),
            )
        # print(patient_id)
        # val_outputs = inference(val_inputs, model_1)
        val_outputs = model_1(val_inputs)
    
        val_outputs_1 = [post_trans(i) for i in decollate_batch(val_outputs)]

        val_outputs_2 = torch.nn.functional.one_hot(torch.argmax(torch.softmax(val_outputs ,dim =1) , dim = 1) ).permute(0,4,1,2,3)

        nib.save(nib.Nifti1Image(val_inputs[0,0,:,:,:].float().detach().cpu().numpy(),np.eye(4)) , filename=f"./output/{patient_id[0]}_ct.nii.gz")
        nib.save(nib.Nifti1Image(val_inputs[0,1,:,:,:].float().detach().cpu().numpy(),np.eye(4)) , filename=f"./output/{patient_id[0]}_mr.nii.gz")
        labels = ['backgroud','CT-A', 'CT-B', 'CT-C', 'CT-D', 'CT-E', 'CT-F', 'CT-G']
        dice_metric = meandice(torch.argmax(torch.softmax(val_outputs ,dim =1) , dim = 1) , torch.argmax(val_labels.int(),dim =1) , 8)
        # print(dice_metric)
        mean_dice.append(dice_metric.item())
        mean_hd95.append(monai.metrics.HausdorffDistanceMetric(include_background = False,percentile=95)(val_outputs_2 , val_labels).mean().item())
        mean_MIOU.append(monai.metrics.MeanIoU(include_background=False)(val_outputs_2 , val_labels).mean().item())

        for i in range(7):
            
            nib.save(nib.Nifti1Image((val_outputs_1[0][i,:,:,:].detach().cpu()>0.5).int().numpy(),np.eye(4)) , filename=f"./output/{patient_id[0]}_{labels[i]}.nii.gz")
        
        for i in range(7):
            nib.save(nib.Nifti1Image(val_labels[0,i,:,:,:].int().detach().cpu().numpy(),np.eye(4)) , filename=f"./output/{patient_id[0]}_{labels[i]}_gt.nii.gz")
        
        nib.save(nib.Nifti1Image(torch.argmax(torch.softmax(val_outputs ,dim =1) , dim = 1)[0,:,:,:].int().detach().cpu().numpy(),np.eye(4)) , filename=f"./output/{patient_id[0]}_pred.nii.gz")
        nib.save(nib.Nifti1Image( torch.argmax(val_labels.int(),dim =1)[0,:,:,:].int().detach().cpu().numpy(),np.eye(4)) , filename=f"./output/{patient_id[0]}_gt.nii.gz")

        # print(val_outputs.shape)
        # break
    
print(f"dice: {mean_dice} mean is : {np.mean(mean_dice) *100}")
print(f"MIOU: {mean_MIOU} mean is : {np.mean(mean_MIOU) *100}")
print(f"hd95: {mean_hd95} mean is : {np.mean(mean_hd95)}")
# Out:
# dice: [0.10148589313030243, 0.0634739100933075] mean is : 8.247990161180496
# MIOU: [0.0647241473197937, 0.035537537187337875] mean is : 5.013084225356579
# hd95: [67.7284164428711, 73.05461120605469] mean is : 70.39151382446289

# %%
torch.argmax(torch.softmax(val_outputs ,dim =1) , dim = 1).shape
# Out:
# torch.Size([1, 128, 128, 128])

# %%
val_outputs_1[0].shape
# Out:
# torch.Size([7, 128, 128, 128])

# %%
for i in range(7):
    print(val_outputs_1[0][i,:,:,:].max())
# Out:
# metatensor(0.9492, device='cuda:0')
# metatensor(0.8301, device='cuda:0')
# metatensor(0.9424, device='cuda:0')
# metatensor(0.8032, device='cuda:0')
# metatensor(0.9282, device='cuda:0')
# metatensor(0.9028, device='cuda:0')
# metatensor(0.9263, device='cuda:0')

# %%
temp_dict = {
    "image" : ["/home/fanxx/fxx/sdc/luoluo/MMWHS/MMWHS/ct_train/ct_train_1001_image.nii.gz",
                "/home/fanxx/fxx/sdc/luoluo/MMWHS/MMWHS/mr_train/mr_train_1001_image.nii.gz"],
    "label" : ["/home/fanxx/fxx/sdc/luoluo/MMWHS/MMWHS/ct_train/ct_train_1001_label.nii.gz",
                "/home/fanxx/fxx/sdc/luoluo/MMWHS/MMWHS/mr_train/mr_train_1001_label.nii.gz"]
}

# %%
from monai import transforms

# %%
roi = (128,128,128)
train_transform = transforms.Compose(
        [
            transforms.LoadImaged(keys=["image", "label"]),
            # transforms.ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
            # transforms.CropForegroundd(
            #     keys=["image", "label"],
            #     source_key="image",
            #     k_divisible=[roi[0], roi[1], roi[2]],
            # ),
            # transforms.RandSpatialCropd(
            #     keys=["image", "label"],
            #     roi_size=[roi[0], roi[1], roi[2]],
            #     random_size=False,
            # ),
            # transforms.RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
            # transforms.RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=1),
            # transforms.RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=2),
            # transforms.NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
            # transforms.RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),
            # transforms.RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),
        ]
    )
# Out:
# /home/fanxx/anaconda3/envs/liulin/lib/python3.9/site-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
